# %%
# !git clone https://github.com/Neuroprosthetics-Lab/nejm-brain-to-text.git
# Out:
# Cloning into 'nejm-brain-to-text'...
# remote: Enumerating objects: 2977, done.
# remote: Counting objects: 100% (218/218), done.
# remote: Compressing objects: 100% (155/155), done.
# remote: Total 2977 (delta 77), reused 63 (delta 63), pack-reused 2759 (from 1)
# Receiving objects: 100% (2977/2977), 80.27 MiB | 37.06 MiB/s, done.
# Resolving deltas: 100% (521/521), done.

# %%
# %cd "/content/nejm-brain-to-text"
# Out:
# /content/nejm-brain-to-text

# %%
# !./setup.sh
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 33.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 24.1.2
#     Uninstalling pip-24.1.2:
#       Successfully uninstalled pip-24.1.2
# ...
# Looking in indexes: https://download.pytorch.org/whl/cu126
# ...
# Obtaining file:///content/nejm-brain-to-text
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.0/16.0 MB 43.5 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 116.2 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 139.0 MB/s  0:00:00
# ...

# %%
# %cd model_training/
# Out:
# /content/nejm-brain-to-text/model_training

# %%
# %cd ..
# !python download_data.py
# Out:
# /content/nejm-brain-to-text
# ...
# Extracting files from t15_copyTask_neuralData.zip ...
# ...
# Extracting files from t15_pretrained_rnn_baseline.zip ...
#
# Download complete. See data files in /content/nejm-brain-to-text/data

# %%
# !python train_model.py
# Out:
# Streaming output truncated to the last 5000 lines.
# Loaded training batch 5325
# Loaded training batch 5326
# Loaded training batch 5327
# Loaded training batch 5328
# Loaded training batch 5329
# Loaded training batch 5330
# Loaded training batch 5331
# Loaded training batch 5332
# Loaded training batch 5333
# Loaded training batch 5334
# Loaded training batch 5335
# Loaded training batch 5336
# Loaded training batch 5337
# Loaded training batch 5338
# Loaded training batch 5339
# Loaded training batch 5340
# Loaded training batch 5341
# Loaded training batch 5342
# Loaded training batch 5343
# Loaded training batch 5344
# Loaded training batch 5345
# Loaded training batch 5346
# Loaded training batch 5347
# Loaded training batch 5348
# Loaded training batch 5349
# Loaded training batch 5350
# Loaded training batch 5351
# Loaded training batch 5352
# Loaded training batch 5353
# Loaded training batch 5354
# Loaded training batch 5355
# Loaded training batch 5356
# ...

# %%
from google.colab import files
import shutil

# %%
# !pwd
# %cd ../..
# Out:
# /content/nejm-brain-to-text/model_training
# /content

# %%
# !rm -rf "/content/nejm-brain-to-text/data"

# %%
shutil.make_archive("my_folder_archive", 'zip', "/content/nejm-brain-to-text")
# Out:
# '/content/my_folder_archive.zip'
